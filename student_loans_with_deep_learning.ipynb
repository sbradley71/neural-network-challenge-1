# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score  credit_ranking
# 0                  9.4               0
# 1                  9.8               0
# 2                  9.8               0
# 3                  9.8               1
# 4                  9.4               0

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df['credit_ranking']

# Display a sample of y
print(y.head())
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop(columns=['credit_ranking'])

# Review the features DataFrame
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score
# 0                  9.4
# 1                  9.8
# 2                  9.8
# 3                  9.8
# 4                  9.4

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# Assign the function a random_state equal to 1
print("Training set - X shape:", X_train.shape, "y shape:", y_train.shape)
print("Testing set - X shape:", X_test.shape, "y shape:", y_test.shape)
# Out:
# Training set - X shape: (1199, 11) y shape: (1199,)
# Testing set - X shape: (400, 11) y shape: (400,)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the scaler to the features training dataset
scaler.fit(X_train)

# Scale the training features dataset
X_train_scaled = scaler.transform(X_train)

# Scale the testing features dataset
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
num_features = 11

# Review the number of features
num_features
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1 = 6

# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2 = 3

# Define the number of neurons in the output layer
output_neurons = 1

# %%
# Create the Sequential model instance
input_shape = 11
model = keras.Sequential()

# Add the first hidden layer
model.add(layers.Dense(hidden_nodes_layer1, activation='relu', input_shape=(input_shape,)))

# Add the second hidden layer
model.add(layers.Dense(hidden_nodes_layer2, activation='relu'))

# Add the output layer to the model specifying the number of output neurons and activation function
model.add(layers.Dense(output_neurons, activation='sigmoid'))

# %%
# Display the Sequential model summary
# Compile the model

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 72
#
#  dense_1 (Dense)             (None, 3)                 21
#
#  dense_2 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 97 (388.00 Byte)
# Trainable params: 97 (388.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Fit the model using 50 epochs and the training data
model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 1s 2ms/step - loss: 0.6929 - accuracy: 0.5313
# Epoch 2/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.5363
# Epoch 3/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6922 - accuracy: 0.5379
# Epoch 4/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6919 - accuracy: 0.5379
# Epoch 5/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6916 - accuracy: 0.5379
# Epoch 6/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6914 - accuracy: 0.5371
# Epoch 7/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6913 - accuracy: 0.5371
# Epoch 8/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6912 - accuracy: 0.5371
# Epoch 9/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6910 - accuracy: 0.5379
# Epoch 10/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6910 - accuracy: 0.5371
# Epoch 11/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6908 - accuracy: 0.5371
# Epoch 12/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6908 - accuracy: 0.5371
# Epoch 13/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6907 - accuracy: 0.5371
# Epoch 14/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6907 - accuracy: 0.5371
# Epoch 15/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6907 - accuracy: 0.5371
# Epoch 16/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5371
# Epoch 17/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6907 - accuracy: 0.5371
# Epoch 18/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5371
# Epoch 19/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6907 - accuracy: 0.5371
# Epoch 20/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5371
# Epoch 21/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5371
# Epoch 22/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5371
# Epoch 23/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5371
# Epoch 24/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6906 - accuracy: 0.5371
# Epoch 25/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5379
# Epoch 26/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5379
# Epoch 27/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5371
# Epoch 28/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5371
# Epoch 29/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5379
# Epoch 30/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5371
# Epoch 31/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5371
# Epoch 32/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5371
# Epoch 33/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5371
# Epoch 34/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5371
# Epoch 35/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6906 - accuracy: 0.5379
# Epoch 36/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5363
# Epoch 37/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5371
# Epoch 38/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5371
# Epoch 39/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5371
# Epoch 40/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5371
# Epoch 41/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5363
# Epoch 42/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5379
# Epoch 43/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5371
# Epoch 44/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5371
# Epoch 45/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6905 - accuracy: 0.5371
# Epoch 46/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6907 - accuracy: 0.5354
# Epoch 47/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6906 - accuracy: 0.5363
# Epoch 48/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5379
# Epoch 49/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5371
# Epoch 50/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6905 - accuracy: 0.5354

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = model.evaluate(X_test, y_test)

# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6914 - accuracy: 0.5300
# Loss: 0.6913535594940186, Accuracy: 0.5299999713897705

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
file_path = Path("student_loans.keras")

# Export your model to a keras file
model.save(file_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
file_path = "student_loans.keras"



# Load the model to a new object
nn_imported = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = nn_imported.predict(X_test)
sample_predictions = predictions[:10]  # Displaying the first 10 predictions as a sample


# Display a sample of the predictions
sample_predictions
# Out:
# 13/13 [==============================] - 0s 2ms/step
# array([[0.53584313],
#        [0.53584313],
#        [0.53584313],
#        [0.53584313],
#        [0.53584313],
#        [0.53584313],
#        [0.53584313],
#        [0.53584313],
#        [0.53584313],
#        [0.53584313]], dtype=float32)

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(predictions, columns=["Predicted Probability"])
predictions_df["Predictions"] = predictions_df["Predicted Probability"].apply(lambda x: 1.0 if x >= 0.5 else 0)

predictions_df
# Out:
#      Predicted Probability  Predictions
# 0                 0.535843          1.0
# 1                 0.535843          1.0
# 2                 0.535843          1.0
# 3                 0.535843          1.0
# 4                 0.535843          1.0
# ..                     ...          ...
# 395               0.524471          1.0
# 396               0.535843          1.0
# 397               0.535843          1.0
# 398               0.535843          1.0
# 399               0.535843          1.0
#
# [400 rows x 2 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, predictions_df["Predictions"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       188
#            1       0.53      1.00      0.69       212
#
#     accuracy                           0.53       400
#    macro avg       0.27      0.50      0.35       400
# weighted avg       0.28      0.53      0.37       400
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# Student Information: Data about the students such as demographics, academic background, current enrollment status, field of study, and any extracurricular activities.
#
# Financial Information: Information about the student's financial situation, including income, expenses, assets, debts, credit history, and any existing loans.
#
# Loan Options Data: Details about different student loan products available, including interest rates, terms, repayment options, and eligibility criteria.
#
# Historical Loan Performance: Data on past loan applications, approvals, rejections, and repayment behavior to assess creditworthiness and predict future repayment patterns.
#
# Feedback and Reviews: Feedback from previous borrowers on their loan experiences, satisfaction levels, and any issues faced during the loan process.
#
# External Factors: Economic indicators, market trends, regulatory changes, and other external factors that may impact loan availability and repayment.
#
# This data is relevant and appropriate because it provides insights into students' financial situations, preferences, and behaviors, which are crucial for recommending suitable loan options tailored to individual needs and circumstances.
#
#
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# A combination of collaborative filtering and content-based filtering.
# The combination of these two filtering methods can provide more personalized and accurate recommendations by considering both user behavior patterns and loan attributes.
#
#
#
#
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.
#
# Data Privacy and Security
# Fairness and Bias
#
# Addressing these challenges is crucial to building a reliable and ethical recommendation system for student loans that prioritizes user privacy, fairness, and transparency.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
# Student Information: Data about the students such as demographics, academic background, current enrollment status, field of study, and any extracurricular activities.
#
# Financial Information: Information about the student's financial situation, including income, expenses, assets, debts, credit history, and any existing loans.
#
# Loan Options Data: Details about different student loan products available, including interest rates, terms, repayment options, and eligibility criteria.
#
# Historical Loan Performance: Data on past loan applications, approvals, rejections, and repayment behavior to assess creditworthiness and predict future repayment patterns.
#
# Feedback and Reviews: Feedback from previous borrowers on their loan experiences, satisfaction levels, and any issues faced during the loan process.
#
# External Factors: Economic indicators, market trends, regulatory changes, and other external factors that may impact loan availability and repayment.
#
# This data is relevant and appropriate because it provides insights into students' financial situations, preferences, and behaviors, which are crucial for recommending suitable loan options tailored to individual needs and circumstances.
#
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
# A combination of collaborative filtering and content-based filtering.
# The combination of these two filtering methods can provide more personalized and accurate recommendations by considering both user behavior patterns and loan attributes.
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
#
# Data Privacy and Security
# Fairness and Bias
#
# Addressing these challenges is crucial to building a reliable and ethical recommendation system for student loans that prioritizes user privacy, fairness, and transparency.
